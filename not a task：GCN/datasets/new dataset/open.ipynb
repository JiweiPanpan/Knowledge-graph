# %%
'''
Load and print datasets for checking
'''
import pickle as pkl
with open('idx2entity.dict', 'rb') as file:
    in_file = pkl.load(file)

    print(in_file)

with open('entities.dict', 'rb') as file:
    in_file = pkl.load(file)

    print(in_file)
# Out:
# {'Measuring': 0, 'the': 1, 'predictability': 2, 'of': 3, 'life': 4, 'outcomes': 5, 'with': 6, 'a': 7, 'scientific': 8, 'mass': 9, 'collaboration': 10, 'research': 11, 'field': 12, 'Science': 13, 'A': 14, 'Joint': 15, 'Model': 16, 'for': 17, 'Representation': 18, 'Learning': 19, 'Tibetan': 20, 'Knowledge': 21, 'Graph': 22, 'Based': 23, 'on': 24, 'Encyclopedia': 25, 'Effects': 26, 'annealing': 27, 'irradiated': 28, 'sic': 29, 'piezoresistive': 30, 'pressure': 31, 'sensor': 32, 'Bacterial': 33, 'growth': 34, 'and': 35, 'primary': 36, 'production': 37, 'along': 38, 'northsouth': 39, 'transect': 40, 'Atlantic': 41, 'Ocean': 42, 'Oceanography': 43, 'generalizability': 44, 'internal': 45, 'external': 46, 'External': 47, 'validity': 48, 'true': 49, 'Flood': 50, 'hazards': 51, 'health': 52, 'responding': 53, 'to': 54, 'present': 55, 'future': 56, 'risks': 57, 'Stark': 58, 'broadening': 59, 'neutral': 60, 'helium': 61, 'lines': 62, 'Plasma': 63, 'Beam': 64, 'Physics': 65, 'Xray': 66, 'laser': 
# ...
